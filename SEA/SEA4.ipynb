# %%
#4qubitのSStronglyEntanglingLayers(https://docs.pennylane.ai/en/stable/code/api/pennylane.StronglyEntanglingLayers.html)
import pennylane as qml
from pennylane import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from pennylane.optimize import AdamOptimizer
from pennylane.optimize import AdagradOptimizer
import matplotlib.pyplot as plt

# %%
#HWE回路のパラメータの読み込み
weights_005= np.load('/home/ryo_mtmt/NTangled_Datasets/Hardware_Efficient/4_Qubits/Depth_6/hwe_4q_ps_5_6_weights.npy')
weights_035= np.load('/home/ryo_mtmt/NTangled_Datasets/Hardware_Efficient/4_Qubits/Depth_6/hwe_4q_ps_35_6_weights.npy')

#データセットの読み込み
train_path = '/home/ryo_mtmt/xanadu_ntangle_dataset/train_HWE_4q_6_005_035_no3.csv'
train_data = np.loadtxt(train_path, delimiter=',',)
X_train = train_data[:, :-1] 
y_train = train_data[:, -1]

test_path = '/home/ryo_mtmt/xanadu_ntangle_dataset/test_HWE_4q_6_005_035_no3.csv'
test_data = np.loadtxt(test_path, delimiter=',',)
X_test = test_data[:, :-1] 
y_test = test_data[:, -1]

# %%
n_wires = 4
dev = qml.device('default.qubit', wires=n_wires)
@qml.qnode(dev)
def circuit(params,x):
    #HWE回路のパラメータの選択
    if x[-1] == -1:
        gen_params = weights_005
    else:
        gen_params = weights_035
    x = x[:-1]
    x = x.reshape( ( int(x.shape[0]/2) , 2) )

    #積状態の入力
    for i in range(n_wires):
        qml.RZ(x[i][1],wires=i)
        qml.RY(x[i][0],wires=i)
    
    #HWE回路
    for layer in range(gen_params.shape[0]):
        for i in range(n_wires):
            qml.U3(gen_params[layer][i][0],gen_params[layer][i][1],gen_params[layer][i][2],wires=i)
        for i in range(int(n_wires/2)):
            qml.CZ(wires=[2*i,2*i+1])
        for i in range(n_wires):
            qml.U3(gen_params[layer][i][0],gen_params[layer][i][1],gen_params[layer][i][2],wires=i)
        for i in range(int((n_wires-1)/2)):
            qml.CZ(wires=[2*i+1,2*i+2])
    
    qml.StronglyEntanglingLayers(params, wires=range(4))

    return qml.expval(qml.PauliZ(0))

# %%
np.random.seed(42)  # ここで好きな整数を指定
shape = qml.StronglyEntanglingLayers.shape(n_layers = 5, n_wires = 4)
params = np.random.random(size=shape)
params.requires_grad = True  # 勾配計算を有効にする

def loss(p):
    predictions = np.array([circuit(p, x) for x in X_train])
    return np.mean((predictions - y_train) ** 2)

opt = AdamOptimizer(0.01)
steps = 200

fig, ax =qml.draw_mpl(circuit)(params, X_train[0])
plt.show()
plt.close()
#print(qml.draw(circuit)(params,X_train[0]))

loss_values = []
loss_values.append(loss(params))
for i in range(steps):
    params = opt.step(loss, params)
    current_loss = loss(params)
    loss_values.append(current_loss)
    print(f"Cost after step {i + 1}: {current_loss}")
        
predictions = np.array([np.sign(circuit(params, x)) for x in X_test])
accuracy = np.mean(predictions == y_test)
print(f"Test accuracy: {accuracy * 100:.2f}%")

print(loss_values)
# Out:
# Cost after step 1: 1.0577636376772375
# Cost after step 2: 1.0491941503705107
# Cost after step 3: 1.0407120899249498
# Cost after step 4: 1.032314898822998
# Cost after step 5: 1.0240359509180568
# Cost after step 6: 1.0159120622444189
# Cost after step 7: 1.0079798280401637
# Cost after step 8: 1.000274202130405
# Cost after step 9: 0.992822559179362
# Cost after step 10: 0.9856391288945638
# Cost after step 11: 0.9787240690895003
# Cost after step 12: 0.9720690639713578
# Cost after step 13: 0.9656664290199483
# Cost after step 14: 0.9595149886192628
# Cost after step 15: 0.9536192894827025
# Cost after step 16: 0.9479845801605457
# Cost after step 17: 0.9426121616386299
# Cost after step 18: 0.9374985672022037
# Cost after step 19: 0.9326383739973468
# Cost after step 20: 0.9280276323672748
# Cost after step 21: 0.9236663300084625
# Cost after step 22: 0.9195598914976205
# Cost after step 23: 0.9157193101136559
# Cost after step 24: 0.9121593630953497
# Cost after step 25: 0.9088950174683441
# Cost after step 26: 0.9059368264144171
# Cost after step 27: 0.9032865100762204
# Cost after step 28: 0.9009339729733441
# Cost after step 29: 0.8988566568455151
# Cost after step 30: 0.8970213677623357
# Cost after step 31: 0.8953878646416844
# Cost after step 32: 0.893913036506909
# Cost after step 33: 0.8925546554951301
# Cost after step 34: 0.8912742489650654
# Cost after step 35: 0.8900391289243808
# Cost after step 36: 0.8888237868587686
# Cost after step 37: 0.8876107654747305
# Cost after step 38: 0.8863908962648611
# Cost after step 39: 0.8851626079814745
# Cost after step 40: 0.8839301276901333
# Cost after step 41: 0.8827008982616883
# Cost after step 42: 0.8814830318960174
# Cost after step 43: 0.8802835782550195
# Cost after step 44: 0.8791077763018647
# Cost after step 45: 0.8779588603730822
# Cost after step 46: 0.8768379352082918
# Cost after step 47: 0.8757437803622227
# Cost after step 48: 0.8746727259947559
# Cost after step 49: 0.8736187870971815
# Cost after step 50: 0.8725741547618378
# Cost after step 51: 0.8715300293086637
# Cost after step 52: 0.8704776747248636
# Cost after step 53: 0.8694094870291909
# Cost after step 54: 0.8683198322367827
# Cost after step 55: 0.8672054628885382
# Cost after step 56: 0.8660654632981862
# Cost after step 57: 0.8649008354811154
# Cost after step 58: 0.8637139317515047
# Cost after step 59: 0.8625079226307172
# Cost after step 60: 0.8612863890129366
# Cost after step 61: 0.8600530212398793
# Cost after step 62: 0.8588113603039239
# Cost after step 63: 0.8575645397060989
# Cost after step 64: 0.8563150448165497
# Cost after step 65: 0.8550645545203633
# Cost after step 66: 0.8538139384300574
# Cost after step 67: 0.8525634433206642
# Cost after step 68: 0.8513130278332746
# Cost after step 69: 0.8500627334044814
# Cost after step 70: 0.8488129613258856
# Cost after step 71: 0.8475645818309925
# Cost after step 72: 0.846318895211786
# Cost after step 73: 0.8450775288763379
# Cost after step 150: 0.8009439614227749
# Cost after step 151: 0.8006854429756707
# Cost after step 152: 0.8004328376740949
# Cost after step 153: 0.8001860738596015
# Cost after step 154: 0.7999450536827221
# Cost after step 155: 0.7997096516765299
# Cost after step 156: 0.7994797143849607
# Cost after step 157: 0.7992550611249736
# Cost after step 158: 0.7990354857204707
# Cost after step 159: 0.7988207589246502
# Cost after step 160: 0.798610631254266
# Cost after step 161: 0.798404836000237
# Cost after step 162: 0.7982030922080264
# Cost after step 163: 0.7980051074791743
# Cost after step 164: 0.7978105805625096
# Cost after step 165: 0.7976192038240228
# Cost after step 166: 0.7974306657213859
# Cost after step 167: 0.7972446533482994
# Cost after step 168: 0.7970608550249826
# Cost after step 169: 0.7968789628626212
# Cost after step 170: 0.7966986752238172
# Cost after step 171: 0.7965196990037945
# Cost after step 172: 0.7963417516606216
# Cost after step 173: 0.7961645629518661
# Cost after step 174: 0.7959878763982637
# Cost after step 175: 0.7958114505585914
# Cost after step 176: 0.7956350602233987
# Cost after step 177: 0.7954584976153417
# Cost after step 178: 0.7952815736500957
# Cost after step 179: 0.7951041192857454
# Cost after step 180: 0.7949259869651556
# Cost after step 181: 0.7947470521250606
# Cost after step 182: 0.7945672147150808
# Cost after step 183: 0.7943864006553014
# Cost after step 184: 0.7942045631626352
# Cost after step 185: 0.7940216838777963
# Cost after step 186: 0.7938377737161443
# Cost after step 187: 0.7936528733550043
# Cost after step 188: 0.7934670532706878
# Cost after step 189: 0.7932804132517866
# Cost after step 190: 0.7930930813332664
# Cost after step 191: 0.792905212114727
# Cost after step 192: 0.7927169844498103
# Cost after step 193: 0.7925285985233514
# Cost after step 194: 0.7923402723614187
# Cost after step 195: 0.7921522378398065
# Cost after step 196: 0.7919647362703617
# Cost after step 197: 0.7917780136584669
# Cost after step 198: 0.7915923157412832
# Cost after step 199: 0.7914078829309733
# Cost after step 200: 0.7912249452967518
# Test accuracy: 55.00%
# [tensor(1.06643465, requires_grad=True), tensor(1.05776364, requires_grad=True), tensor(1.04919415, requires_grad=True), tensor(1.04071209, requires_grad=True), tensor(1.0323149, requires_grad=True), tensor(1.02403595, requires_grad=True), tensor(1.01591206, requires_grad=True), tensor(1.00797983, requires_grad=True), tensor(1.0002742, requires_grad=True), tensor(0.99282256, requires_grad=True), tensor(0.98563913, requires_grad=True), tensor(0.97872407, requires_grad=True), tensor(0.97206906, requires_grad=True), tensor(0.96566643, requires_grad=True), tensor(0.95951499, requires_grad=True), tensor(0.95361929, requires_grad=True), tensor(0.94798458, requires_grad=True), tensor(0.94261216, requires_grad=True), tensor(0.93749857, requires_grad=True), tensor(0.93263837, requires_grad=True), tensor(0.92802763, requires_grad=True), tensor(0.92366633, requires_grad=True), tensor(0.91955989, requires_grad=True), tensor(0.91571931, requires_grad=True), tensor(0.91215936, requires_grad=True), tensor(0.90889502, requires_grad=True), tensor(0.90593683, requires_grad=True), tensor(0.90328651, requires_grad=True), tensor(0.90093397, requires_grad=True), tensor(0.89885666, requires_grad=True), tensor(0.89702137, requires_grad=True), tensor(0.89538786, requires_grad=True), tensor(0.89391304, requires_grad=True), tensor(0.89255466, requires_grad=True), tensor(0.89127425, requires_grad=True), tensor(0.89003913, requires_grad=True), tensor(0.88882379, requires_grad=True), tensor(0.88761077, requires_grad=True), tensor(0.8863909, requires_grad=True), tensor(0.88516261, requires_grad=True), tensor(0.88393013, requires_grad=True), tensor(0.8827009, requires_grad=True), tensor(0.88148303, requires_grad=True), tensor(0.88028358, requires_grad=True), tensor(0.87910778, requires_grad=True), tensor(0.87795886, requires_grad=True), tensor(0.87683794, requires_grad=True), tensor(0.87574378, requires_grad=True), tensor(0.87467273, requires_grad=True), tensor(0.87361879, requires_grad=True), tensor(0.87257415, requires_grad=True), tensor(0.87153003, requires_grad=True), tensor(0.87047767, requires_grad=True), tensor(0.86940949, requires_grad=True), tensor(0.86831983, requires_grad=True), tensor(0.86720546, requires_grad=True), tensor(0.86606546, requires_grad=True), tensor(0.86490084, requires_grad=True), tensor(0.86371393, requires_grad=True), tensor(0.86250792, requires_grad=True), tensor(0.86128639, requires_grad=True), tensor(0.86005302, requires_grad=True), tensor(0.85881136, requires_grad=True), tensor(0.85756454, requires_grad=True), tensor(0.85631504, requires_grad=True), tensor(0.85506455, requires_grad=True), tensor(0.85381394, requires_grad=True), tensor(0.85256344, requires_grad=True), tensor(0.85131303, requires_grad=True), tensor(0.85006273, requires_grad=True), tensor(0.84881296, requires_grad=True), tensor(0.84756458, requires_grad=True), tensor(0.8463189, requires_grad=True), tensor(0.84507753, requires_grad=True), tensor(0.84384235, requires_grad=True), tensor(0.8426154, requires_grad=True), tensor(0.84139887, requires_grad=True), tensor(0.84019502, requires_grad=True), tensor(0.83900613, requires_grad=True), tensor(0.83783451, requires_grad=True), tensor(0.83668252, requires_grad=True), tensor(0.83555267, requires_grad=True), tensor(0.83444774, requires_grad=True), tensor(0.8333707, requires_grad=True), tensor(0.83232459, requires_grad=True), tensor(0.83131236, requires_grad=True), tensor(0.83033665, requires_grad=True), tensor(0.82939962, requires_grad=True), tensor(0.82850283, requires_grad=True), tensor(0.82764715, requires_grad=True), tensor(0.82683266, requires_grad=True), tensor(0.82605865, requires_grad=True), tensor(0.82532367, requires_grad=True), tensor(0.8246257, requires_grad=True), tensor(0.82396222, requires_grad=True), tensor(0.82333037, requires_grad=True), tensor(0.82272708, requires_grad=True), tensor(0.82214915, requires_grad=True), tensor(0.82159337, requires_grad=True), tensor(0.82105662, requires_grad=True), tensor( ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(0, steps + 1), loss_values, marker='.')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1.5])
plt.grid()
plt.show()
